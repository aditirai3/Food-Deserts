# %%
# Dependencies
import requests
import json
import gmaps
import pandas as pd

# %%
Wikiurl = 'https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States'

# %%
# use read_html to scrape out tables and select the relevant table
tables = pd.read_html(Wikiurl)[0]
tables.head()
# Out:
#   Flag, name andpostal abbreviation[12]  \
#   Flag, name andpostal abbreviation[12]
# 0                               Alabama
# 1                                Alaska
# 2                               Arizona
# 3                              Arkansas
# 4                            California
#
#                                                 Cities               \
#   Flag, name andpostal abbreviation[12].1      Capital  Largest[16]
# 0                                      AL   Montgomery   Birmingham
# 1                                      AK       Juneau    Anchorage
# 2                                      AZ      Phoenix      Phoenix
# 3                                      AR  Little Rock  Little Rock
# 4                                      CA   Sacramento  Los Angeles
#
#   Ratification oradmission[C] Population[D][14] Total area[15]           \
#   Ratification oradmission[C] Population[D][14]            mi2      km2
# ...

# %%
tables.columns = tables.columns.droplevel()

# %%
tables.rename(columns = {'Flag, name andpostal abbreviation[12]':'State'}, inplace = True)

# %%
tables.head()
# Out:
#         State Flag, name andpostal abbreviation[12].1      Capital  \
# 0     Alabama                                      AL   Montgomery
# 1      Alaska                                      AK       Juneau
# 2     Arizona                                      AZ      Phoenix
# 3    Arkansas                                      AR  Little Rock
# 4  California                                      CA   Sacramento
#
#    Largest[16] Ratification oradmission[C]  Population[D][14]     mi2  \
# 0   Birmingham                Dec 14, 1819            4903185   52420
# 1    Anchorage                 Jan 3, 1959             731545  665384
# 2      Phoenix                Feb 14, 1912            7278717  113990
# 3  Little Rock                Jun 15, 1836            3017804   53179
# 4  Los Angeles                 Sep 9, 1850           39512223  163695
#
#        km2     mi2      km2    mi2     km2  Numberof Reps.
# 0   135767   50645   131171   1775    4597               7
# ...

# %%
tables = tables.drop(columns = ['Flag, name andpostal abbreviation[12].1', 'Capital', 'Largest[16]', 'Ratification oradmission[C]', 'Population[D][14]', 'mi2', 'km2', 'Numberof Reps.'])

# %%
tables.at[16, 'State']= "Kentucky"
tables.at[20, 'State']= "Massachusetts"
tables.at[37, 'State']= "Pennsylvania"
tables.at[45, 'State']= "Virginia"

# %%
tables
# Out:
#              State
# 0          Alabama
# 1           Alaska
# 2          Arizona
# 3         Arkansas
# 4       California
# 5         Colorado
# 6      Connecticut
# 7         Delaware
# 8          Florida
# 9          Georgia
# 10          Hawaii
# 11           Idaho
# 12        Illinois
# 13         Indiana
# 14            Iowa
# 15          Kansas
# 16        Kentucky
# 17       Louisiana
# 18           Maine
# 19        Maryland
# 20   Massachusetts
# 21        Michigan
# 22       Minnesota
# 23     Mississippi
# 24        Missouri
# 25         Montana
# 26        Nebraska
# 27          Nevada
# 28   New Hampshire
# 29      New Jersey
# 30      New Mexico
# 31        New York
# 32  North Carolina
# 33    North Dakota
# 34            Ohio
# 35        Oklahoma
# 36          Oregon
# 37    Pennsylvania
# 38    Rhode Island
# 39  South Carolina
# 40    South Dakota
# 41       Tennessee
# 42           Texas
# 43            Utah
# 44         Vermont
# 45        Virginia
# ...

# %%
tables["Latitude"] = ""
tables["Longitude"] = ""
tables["Grocery Stores"] = ""
# Out:
# <ipython-input-73-4cdc897e42dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tables["Latitude"] = ""
# <ipython-input-73-4cdc897e42dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tables["Longitude"] = ""
# <ipython-input-73-4cdc897e42dc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
tables
# Out:
#              State      Lat      Lng               Grocery Stores Latitude  \
# 0          Alabama  32.3182 -86.9023                   Winn-Dixie  32.3182
# 1           Alaska  64.2008 -149.494            Three Bears Healy  64.2008
# 2          Arizona  34.0489 -111.094                     Speedway  34.0489
# 3         Arkansas  35.2011 -91.8318          Walmart Supercenter  35.2011
# 4       California  36.7783 -119.418          Walmart Supercenter  36.7783
# 5         Colorado  39.5501 -105.782                      Walmart  39.5501
# 6      Connecticut  41.6032 -73.0877               Stew Leonard's  41.6032
# 7         Delaware  38.9108 -75.5277          Walmart Supercenter  38.9108
# 8          Florida  27.6648 -81.5158          Walmart Supercenter  27.6648
# 9          Georgia  32.1656 -82.9001                   Cash Saver  32.1656
# 10          Hawaii  19.8968 -155.583                     Foodland  19.8968
# ...

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": "AIzaSyBiTRcGCSJDHIgUPNKGVzTBYmd6uliMzRU"}

# Loop through the cities_pd and run a lat/long search for each state
for index, row in tables.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    state = row['State']

    # update address key value
    params['address'] = f"{state}"

    # make request
    state_lat_lng = requests.get(base_url, params=params)
    
    # convert to json
    state_lat_lng = state_lat_lng.json()

    tables.loc[index, "Latitude"] = state_lat_lng["results"][0]["geometry"]["location"]["lat"]
    tables.loc[index, "Longitude"] = state_lat_lng["results"][0]["geometry"]["location"]["lng"]

# Visualize to confirm lat lng appear
tables.head()
# Out:
# /Users/aditirai/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-75-4e52c3defd9b>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tables.loc[index, "Latitude"] = state_lat_lng["results"][0]["geometry"]["location"]["lat"]
# <ipython-input-75-4e52c3defd9b>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# **Extract California Stores**

# %%
# referenced from https://stackoverflow.com/questions/46578128/pandas-read-jsonjson-url
from urllib.request import urlopen

# %%
CA_stores = urlopen("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=36.7783,%20-119.418&radius=50000&keyword=Grocery%20store&key=AIzaSyBiTRcGCSJDHIgUPNKGVzTBYmd6uliMzRU")
json_data = CA_stores.read()

# %%
d = json.loads(json_data)

# %%
df = pd.json_normalize(d['results'])

# %%
df.head()
# Out:
#   business_status                                               icon  \
# 0     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#              name                                             photos  \
# 0       Foods Co.  [{'height': 1080, 'html_attributions': ['<a hr...
# 1       Foods Co.  [{'height': 3120, 'html_attributions': ['<a hr...
# 2      The Market  [{'height': 3024, 'html_attributions': ['<a hr...
# 3     Food 4 Less  [{'height': 3120, 'html_attributions': ['<a hr...
# 4  Grocery Outlet  [{'height': 4008, 'html_attributions': ['<a hr...
#
#                       place_id  rating                    reference   scope  \
# ...

# %%
df = df.drop(columns = ['business_status', 'icon', 'photos', 'place_id', 'rating', 'reference', 'scope', 'types', 'user_ratings_total', 'geometry.viewport.northeast.lat', 'geometry.viewport.northeast.lng', 'geometry.viewport.southwest.lat', 'geometry.viewport.southwest.lng', 'opening_hours.open_now', 'plus_code.global_code', 'price_level'])

# %%
df.head()
# Out:
#              name                        vicinity  geometry.location.lat  \
# 0       Foods Co.  4838 E Kings Canyon Rd, Fresno              36.734168
# 1       Foods Co.         3657 W Shaw Ave, Fresno              36.806153
# 2      The Market         7088 N West Ave, Fresno              36.838813
# 3     Food 4 Less     8921 N Chestnut Ave, Fresno              36.865278
# 4  Grocery Outlet         1848 Clovis Ave, Clovis              36.809360
#
#    geometry.location.lng     plus_code.compound_code
# 0            -119.735028  P7M7+MX Fresno, California
# 1            -119.859586  R44R+F5 Fresno, California
# 2            -119.824941  R5QG+G2 Fresno, California
# 3            -119.740556  V785+4Q Fresno, California
# 4            -119.701390  R75X+PC Clovis, California

# %%
df[['plus_code.compound_code','State']] = df['plus_code.compound_code'].str.split(',',expand=True)

# %%
df.head()
# Out:
#              name                        vicinity  geometry.location.lat  \
# 0       Foods Co.  4838 E Kings Canyon Rd, Fresno              36.734168
# 1       Foods Co.         3657 W Shaw Ave, Fresno              36.806153
# 2      The Market         7088 N West Ave, Fresno              36.838813
# 3     Food 4 Less     8921 N Chestnut Ave, Fresno              36.865278
# 4  Grocery Outlet         1848 Clovis Ave, Clovis              36.809360
#
#    geometry.location.lng plus_code.compound_code        State
# 0            -119.735028          P7M7+MX Fresno   California
# 1            -119.859586          R44R+F5 Fresno   California
# 2            -119.824941          R5QG+G2 Fresno   California
# 3            -119.740556          V785+4Q Fresno   California
# 4            -119.701390          R75X+PC Clovis   California

# %%
df = df.drop(columns=['vicinity', 'plus_code.compound_code'])

# %%
df.head()
# Out:
#              name  geometry.location.lat  geometry.location.lng        State
# 0       Foods Co.              36.734168            -119.735028   California
# 1       Foods Co.              36.806153            -119.859586   California
# 2      The Market              36.838813            -119.824941   California
# 3     Food 4 Less              36.865278            -119.740556   California
# 4  Grocery Outlet              36.809360            -119.701390   California

# %%
df.to_csv("california_stores", header=True)
